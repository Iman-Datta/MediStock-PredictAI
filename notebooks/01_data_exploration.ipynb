# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Dataset/smart_pharmacy_dataset.csv")

df.head()
# Out:
#   medicine_id medicine_name           category  year  week_number  season  \
# 0      MED001   Paracetamol  Fever/Pain Relief  2023            1  Winter
# 1      MED001   Paracetamol  Fever/Pain Relief  2023            2  Winter
# 2      MED001   Paracetamol  Fever/Pain Relief  2023            3  Winter
# 3      MED001   Paracetamol  Fever/Pain Relief  2023            4  Winter
# 4      MED001   Paracetamol  Fever/Pain Relief  2023            5  Winter
#
#    current_stock  previous_week_sales  sales_last_2_week  \
# 0           1137                  355                355
# 1             12                  355                291
# 2             26                  291                355
# 3            641                  248                291
# 4            407                  257                248
#
#    sales_last_4_week_average  flu_cases  dengue_cases  covid_cases  \
# 0                     355.00        376            19           42
# ...

# %%
df = df.sort_values(
    by=["year", "week_number", "medicine_id"]
)

df.head()
# Out:
#     medicine_id medicine_name           category  year  week_number  season  \
# 0        MED001   Paracetamol  Fever/Pain Relief  2023            1  Winter
# 156      MED002     Ibuprofen  Fever/Pain Relief  2023            1  Winter
# 312      MED003       Aspirin  Fever/Pain Relief  2023            1  Winter
# 468      MED004    Diclofenac  Fever/Pain Relief  2023            1  Winter
# 624      MED005      Naproxen  Fever/Pain Relief  2023            1  Winter
#
#      current_stock  previous_week_sales  sales_last_2_week  \
# 0             1137                  355                355
# 156            635                  234                234
# 312            420                  267                267
# 468            237                   95                 95
# 624            225                   89                 89
#
#      sales_last_4_week_average  flu_cases  dengue_cases  covid_cases  \
# 0                        355.0        376            19           42
# ...

# %%
df.shape
# Out:
# (23400, 19)

# %%
df.columns
# Out:
# Index(['medicine_id', 'medicine_name', 'category', 'year', 'week_number',
#        'season', 'current_stock', 'previous_week_sales', 'sales_last_2_week',
#        'sales_last_4_week_average', 'flu_cases', 'dengue_cases', 'covid_cases',
#        'supplier_delivery_days', 'stock_received', 'expiry_risk',
#        'is_holiday_week', 'medicine_importance', 'next_week_demand'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 23400 entries, 0 to 23399
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   medicine_id                23400 non-null  str
#  1   medicine_name              23400 non-null  str
#  2   category                   23400 non-null  str
#  3   year                       23400 non-null  int64
#  4   week_number                23400 non-null  int64
#  5   season                     23400 non-null  str
#  6   current_stock              23400 non-null  int64
#  7   previous_week_sales        23400 non-null  int64
#  8   sales_last_2_week          23400 non-null  int64
#  9   sales_last_4_week_average  23400 non-null  float64
#  10  flu_cases                  23400 non-null  int64
#  11  dengue_cases               23400 non-null  int64
#  12  covid_cases                23400 non-null  int64
#  13  supplier_delivery_days     23400 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# medicine_id                  0
# medicine_name                0
# category                     0
# year                         0
# week_number                  0
# season                       0
# current_stock                0
# previous_week_sales          0
# sales_last_2_week            0
# sales_last_4_week_average    0
# flu_cases                    0
# dengue_cases                 0
# covid_cases                  0
# supplier_delivery_days       0
# stock_received               0
# expiry_risk                  0
# is_holiday_week              0
# medicine_importance          0
# next_week_demand             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["medicine_id"].nunique() # medicine count
# Out:
# 150

# %%
df.groupby("medicine_id")["week_number"].count()
# Out:
# medicine_id
# MED001    156
# MED002    156
# MED003    156
# MED004    156
# MED005    156
#          ...
# MED146    156
# MED147    156
# MED148    156
# MED149    156
# MED150    156
# Name: week_number, Length: 150, dtype: int64

# %%
df.describe()
# Out:
#                year   week_number  current_stock  previous_week_sales  \
# count  23400.000000  23400.000000   23400.000000         23400.000000
# mean    2024.000000     26.500000     109.840214            55.427564
# std        0.816514     15.008652     101.593684            41.061300
# min     2023.000000      1.000000       1.000000             7.000000
# 25%     2023.000000     13.750000      48.000000            29.000000
# 50%     2024.000000     26.500000      82.000000            44.000000
# 75%     2025.000000     39.250000     139.000000            69.000000
# max     2025.000000     52.000000    1377.000000           435.000000
#
#        sales_last_2_week  sales_last_4_week_average     flu_cases  \
# count       23400.000000               23400.000000  23400.000000
# mean           55.433034                  55.458846    159.884316
# std            41.074837                  39.784539    127.159569
# min             7.000000                   8.000000     23.000000
# ...
